# %%
from model.Train import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs = load_dfs()
print(songs.head())
# Out:
#    is_bjork_inspo  danceability  energy  key  loudness  mode  speechiness  \
# 0            True         0.690   0.640    8    -9.981     0       0.0842
# 1            True         0.828   0.346    7   -17.820     0       0.0582
# 2            True         0.591   0.431    7   -16.228     1       0.0624
# 3            True         0.674   0.310    9   -15.314     0       0.0326
# 4            True         0.590   0.482    0   -13.997     1       0.0754
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.519          0.000025    0.0545    0.796  145.740       209333
# 1         0.658          0.000013    0.2200    0.780  122.877       205173
# 2         0.649          0.000421    0.1210    0.684  114.806       326693
# 3         0.552          0.000000    0.0947    0.690  105.235       235107
# 4         0.397          0.000004    0.1180    0.798   91.950       200360
#
#    time_signature  num_bars  num_sections  num_segments
# ...

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['is_bjork_inspo']==1]['danceability'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['danceability'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['is_bjork_inspo']==1]['energy'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['energy'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['is_bjork_inspo']==1]['key'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['key'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['is_bjork_inspo']==1]['loudness'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['loudness'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['is_bjork_inspo']==1]['mode'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['mode'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['is_bjork_inspo']==1]['acousticness'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['acousticness'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['is_bjork_inspo']==1]['instrumentalness'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['instrumentalness'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['is_bjork_inspo']==1]['liveness'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['liveness'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['is_bjork_inspo']==1]['valence'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['valence'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['is_bjork_inspo']==1]['tempo'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['tempo'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['is_bjork_inspo']==1]['duration_ms'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['duration_ms'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['is_bjork_inspo']==1]['time_signature'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['time_signature'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['is_bjork_inspo']==1]['num_bars'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['num_bars'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['is_bjork_inspo']==1]['num_sections'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['num_sections'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['is_bjork_inspo']==1]['num_segments'], color='red', bins=40)
sns.distplot(songs[songs['is_bjork_inspo']==0]['num_segments'], color='blue', bins=40)
plt.legend((1,0))
